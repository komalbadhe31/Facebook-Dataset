# %% [markdown]
# **GROUP B: Assignment No - 1**

# %% [markdown]
# ### Title:
# Perform the following operations using Python on the Facebook metrics data sets
#
# a. Create data subsets
#
# b. Merge Data
#
# c. Sort Data
#
# d. Transposing Data
#
# e. Shape and reshape Data

# %% [markdown]
# **Name**: Komal P. Badhe

# %% [markdown]
# **Roll No**: 20013069

# %% [markdown]
# **Class:** TE-IT

# %% [markdown]
# #Importing the required Libraries

# %%
import pandas as pd;
import numpy as np;

# %% [markdown]
# #Reading the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#data = pd.read_csv("dataset_Facebook.csv", sep=';');


data = pd.read_csv("/content/drive/MyDrive/Dataset/dataset_Facebook.csv", sep=';');

data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
ndata = data.isnull().dropna()
ndata
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0               False  False     False       False         False      False
# 1               False  False     False       False         False      False
# 2               False  False     False       False         False      False
# 3               False  False     False       False         False      False
# 4               False  False     False       False         False      False
# ..                ...    ...       ...         ...           ...        ...
# 495             False  False     False       False         False      False
# 496             False  False     False       False         False      False
# 497             False  False     False       False         False      False
# 498             False  False     False       False         False      False
# 499             False  False     False       False         False      False
#
# ...

# %% [markdown]
# **Getting shape of dataset**

# %%
data.shape
# Out:
# (500, 19)

# %% [markdown]
# #Creating subsets

# %%
subset1 = data.loc[:80, :]

subset1
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441   Photo         2          12             4          3
# 1             139441  Status         2          12             3         10
# 2             139441   Photo         3          12             3          3
# 3             139441   Photo         2          12             2         10
# 4             139441   Photo         2          12             2          3
# ..               ...     ...       ...         ...           ...        ...
# 76            137893   Photo         1          11             3          2
# 77            137177   Photo         1          11             1         10
# 78            137177   Photo         2          11             1          3
# 79            137177   Photo         1          11             7         12
# 80            137177  Status         2          11             7          3
#
# ...

# %%
subset2 = data.loc[81:160, :]

subset2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 81             137177   Photo         3          11             6         10
# 82             137177   Photo         1          11             6          3
# 83             137177   Photo         3          11             5         10
# 84             137177  Status         3          11             5          2
# 85             137177   Photo         1          11             4          9
# ..                ...     ...       ...         ...           ...        ...
# 156            135700   Photo         2           9             2         11
# 157            135700   Photo         3           9             2          2
# 158            135700   Photo         2           9             1         10
# 159            135617   Photo         2           9             1          3
# 160            135617   Photo         3           9             7          9
#
# ...

# %% [markdown]
# #Merging dataset

# %%
#outer

om_data = subset1.merge(subset2, how='outer')


om_data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 156            135700   Photo         2           9             2         11
# 157            135700   Photo         3           9             2          2
# 158            135700   Photo         2           9             1         10
# 159            135617   Photo         2           9             1          3
# 160            135617   Photo         3           9             7          9
#
# ...

# %%
#Concat 

frames = [subset1, subset2]

result = pd.concat(frames)

result
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 156            135700   Photo         2           9             2         11
# 157            135700   Photo         3           9             2          2
# 158            135700   Photo         2           9             1         10
# 159            135617   Photo         2           9             1          3
# 160            135617   Photo         3           9             7          9
#
# ...

# %% [markdown]
# #Sorting dataset

# %%
#Ascending order

sorted_category = data.sort_values(by=['Category'])

sorted_category
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 128            136393  Photo         1          10             6         13
# 144            136013  Photo         1          10             2          3
# 145            136013  Photo         1          10             1         10
# 402            107907  Photo         1           4             3          4
# 401            107907  Photo         1           4             3         13
# ..                ...    ...       ...         ...           ...        ...
# 356            116435  Photo         3           5             1         13
# 359            116091  Photo         3           5             7          2
# 361            116091  Photo         3           5             6          3
# 143            136013  Photo         3          10             2         10
# 162            135617  Photo         3           9             6         10
#
# ...

# %%
#descending order

sorted_Post_months = data.sort_values(by=['Post Month'], ascending = False)


sorted_Post_months
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 38             138895  Status         2          12             7          9
# 28             138895   Photo         2          12             5          3
# 29             138895   Video         1          12             4         11
# 30             138895   Photo         2          12             4          2
# ..                ...     ...       ...         ...           ...        ...
# 478             86909   Photo         3           1             5         13
# 477             86909    Link         1           1             6          4
# 476             86909   Photo         1           1             6         10
# 475             86909   Photo         3           1             6         16
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
#Sorting multiple columns

cp = data.sort_values(by=['Category', 'Post Month'])

cp
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 476             86909  Photo         1           1             6         10
# 477             86909   Link         1           1             6          4
# 481             86491   Link         1           1             4          4
# 485             86491   Link         1           1             2          2
# 492             85979   Link         1           1             5         11
# ..                ...    ...       ...         ...           ...        ...
# 23             138414  Photo         3          12             7          3
# 27             138458  Photo         3          12             5          3
# 32             138895  Photo         3          12             3          3
# 33             138895  Photo         3          12             2          9
# 36             138895  Photo         3          12             1          3
#
# ...

# %% [markdown]
# #Transpose

# %%
t_data = data.transpose()

t_data
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
T_data = data.T

T_data
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %% [markdown]
# #Reshaping

# %%
pdata = data[['like',	'share' , 'Category', 'Type']]


p = pdata.pivot_table(index=['Category','like'])

p
# Out:
#                       share
# Category like
# 1        0.0       0.000000
#          1.0       2.000000
#          2.0       0.000000
#          3.0       0.666667
#          4.0       1.000000
# ...                     ...
# 3        1155.0  102.000000
#          1372.0   47.000000
#          1546.0  181.000000
#          1639.0  122.000000
#          1998.0  128.000000
#
# [368 rows x 1 columns]

# %%
p.reset_index(inplace = True)

p
# Out:
#      Category    like       share
# 0           1     0.0    0.000000
# 1           1     1.0    2.000000
# 2           1     2.0    0.000000
# 3           1     3.0    0.666667
# 4           1     4.0    1.000000
# ..        ...     ...         ...
# 363         3  1155.0  102.000000
# 364         3  1372.0   47.000000
# 365         3  1546.0  181.000000
# 366         3  1639.0  122.000000
# 367         3  1998.0  128.000000
#
# [368 rows x 3 columns]

# %%
pd.melt(data,  value_vars =['like','share'])
# Out:
#     variable   value
# 0       like    79.0
# 1       like   130.0
# 2       like    66.0
# 3       like  1572.0
# 4       like   325.0
# ..       ...     ...
# 995    share    26.0
# 996    share    22.0
# 997    share    18.0
# 998    share    38.0
# 999    share    28.0
#
# [1000 rows x 2 columns]

# %%
data.pivot(columns='Category', values='like')
# Out:
# Category     1       2     3
# 0          NaN    79.0   NaN
# 1          NaN   130.0   NaN
# 2          NaN     NaN  66.0
# 3          NaN  1572.0   NaN
# 4          NaN   325.0   NaN
# ..         ...     ...   ...
# 495        NaN     NaN  53.0
# 496        NaN    53.0   NaN
# 497       93.0     NaN   NaN
# 498        NaN     NaN  91.0
# 499        NaN    91.0   NaN
#
# [500 rows x 3 columns]
